# %% [markdown]
# [이 노트북](https://github.com/chhyyi/aiffelthon/blob/main/cvae_poc/cvae_poc.ipynb)으로 만든 list_attr.csv 파일의 새 버전입니다.
# path_RI, path_CHL을 수정해주세요.

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import os
path_RI = 'sample_img/imgCrop_RI'
path_CHL = 'sample_img/imgCrop_CHL'

sample_chls=os.listdir(path_CHL)
sample_chls=[os.path.join(path_CHL, i) for i in sample_chls]
sample_ris=os.listdir(path_RI)
sample_ris=[os.path.join(path_RI, i) for i in sample_ris]

#print(sample_chls)
print(len(sample_chls), len(sample_ris))
# Out:
# 1517 1516

# %%
import pandas as pd
sample_chls_fn_split=[list(i.split('/')[-1].split('.')[0].split('_'))+[i] for i in sample_chls]
sample_ris_fn_split=[list(i.split('/')[-1].split('.')[0].split('_'))+[i] for i in sample_ris]

# %%
print(sample_chls_fn_split[0], sample_ris_fn_split[0])
# Out:
# ['20210922', '13', 'CHL', 'sample_img/imgCrop_CHL/20210922_13_CHL.jpg'] ['20210928', '08', 'RI', 'sample_img/imgCrop_RI/20210928_08_RI.jpg']

# %%
sample_chls_df=pd.DataFrame(sample_chls_fn_split, columns=['date', 'hour', 'product','file'])
sample_ris_df=pd.DataFrame(sample_ris_fn_split, columns=['date', 'hour', 'product','file'])

sample_ris_df.dropna(inplace=True)

sample_chls_df.dropna(inplace=True)

sample_chls_df.sort_values(by=['date', 'hour'], inplace=True)
sample_ris_df.sort_values(by=['date', 'hour'], inplace=True)

sample_ris_df['year']=sample_ris_df['date'].astype('datetime64[D]').apply(lambda x:x.year)
sample_ris_df['mm']=sample_ris_df['date'].astype('datetime64[D]').apply(lambda x:x.month)
sample_ris_df['dd']=sample_ris_df['date'].astype('datetime64[D]').apply(lambda x:x.day)
sample_ris_df['hh']=sample_ris_df['hour'].astype('int')

sample_ris_df.drop(columns=['date', 'hour'], inplace=True)
sample_ris_df.reset_index(drop=True, inplace=True)

sample_chls_df['year']=sample_chls_df['date'].astype('datetime64[D]').apply(lambda x:x.year)
sample_chls_df['mm']=sample_chls_df['date'].astype('datetime64[D]').apply(lambda x:x.month)
sample_chls_df['dd']=sample_chls_df['date'].astype('datetime64[D]').apply(lambda x:x.day)
sample_chls_df['hh']=sample_chls_df['hour'].astype('int')

sample_chls_df.drop(columns=['date', 'hour'], inplace=True)
sample_chls_df.reset_index(drop=True, inplace=True)



sensory=pd.read_csv('observe_train_refined_with_datetime.csv', index_col = 0)
sensory.drop(columns='interpolated', inplace=True)

# %%
sensory.iloc[:,:-5]=(sensory.iloc[:,:-5]-sensory.iloc[:,:-5].min())/(sensory.iloc[:,:-5].max()-sensory.iloc[:,:-5].min()) #distributed 0~1
sensory
# Out:
#         풍속(m/s)   풍향(deg)    기온(°C)    수온(°C)  강수량(mm)  풍속(m/s).1  풍향(deg).1  \
# 39     0.136364  0.838889  0.458549  0.383562      0.0   0.047297   0.741667
# 40     0.210744  0.825000  0.468912  0.388128      0.0   0.033784   0.711111
# 41     0.194215  0.852778  0.479275  0.383562      0.0   0.057432   0.675000
# 42     0.206612  0.813889  0.489637  0.360731      0.0   0.047297   0.711111
# 43     0.276860  0.891667  0.484456  0.347032      0.0   0.226351   0.769444
# ...         ...       ...       ...       ...      ...        ...        ...
# 50370  0.016529  0.580556  0.707254  0.707763      0.0   0.097973   0.386111
# 50371  0.066116  0.602778  0.709845  0.698630      0.0   0.108108   0.400000
# 50372  0.066116  0.691667  0.707254  0.698630      0.0   0.091216   0.400000
# 50373  0.082645  0.730556  0.699482  0.716895      0.0   0.060811   0.497222
# 50374  0.095041  0.744444  0.699482  0.721461      0.0   0.064189   0.555556
#
#        기온(°C).1  수온(°C).1  강수량(mm).1  ...  풍속(m/s).4  풍향(deg).4  기온(°C).4  \
# 39     0.492308  0.243386        0.0  ...   0.078603   0.986111  0.748936
# 40     0.505128  0.253968        0.0  ...   0.213974   0.013889  0.746099
# 41     0.500000  0.248677        0.0  ...   0.248908   0.927778  0.747518
# 42     0.512821  0.243386        0.0  ...   0.192140   0.930556  0.753191
# 43     0.530769  0.238095        0.0  ...   0.288210   0.016667  0.751773
# ...         ...       ...        ...  ...        ...        ...       ...
# 50370  0.776923  0.693122        0.0  ...   0.052402   0.016667  0.878014
# 50371  0.769231  0.687831        0.0  ...   0.074236   0.052778  0.843972
# 50372  0.769231  0.682540        0.0  ...   0.048035   0.961111  0.822695
# 50373  0.761538  0.682540        0.0  ...   0.048035   0.922222  0.858156
# 50374  0.764103  0.687831        0.0  ...   0.096070   0.966667  0.814184
#
#        수온(°C).4  강수량(mm).4  적조발생  year  mm  dd  hh
# 39     0.368421        0.0   0.0  2017   1   2  16
# 40     0.364372        0.0   0.0  2017   1   2  17
# 41     0.364372        0.0   0.0  2017   1   2  18
# 42     0.364372        0.0   0.0  2017   1   2  19
# 43     0.368421        0.0   0.0  2017   1   2  20
# ...         ...        ...   ...   ...  ..  ..  ..
# 50370  0.732794        0.0   0.0  2022   9  30  19
# 50371  0.696356        0.0   0.0  2022   9  30  20
# 50372  0.684211        0.0   0.0  2022   9  30  21
# 50373  0.676113        0.0   0.0  2022   9  30  22
# 50374  0.676113        0.0   0.0  2022   9  30  23
#
# [50336 rows x 30 columns]

# %% [markdown]
# ## 실제 DF 통합

# %%
sample_ris_df = sample_ris_df.drop(columns='product')
sample_chls_df=sample_chls_df.drop(columns='product')

# %%
sample_ris_df = sample_ris_df.rename(columns={'file':'RI_file'})
sample_chls_df = sample_chls_df.rename(columns={'file':'CHL_file'})

# %%
dt_index=['year', 'mm', 'dd', 'hh']

merged_df=sample_ris_df.merge(sample_chls_df, how='left', on=dt_index)
merged_df
# Out:
#                                        RI_file  year  mm  dd  hh  \
# 0     sample_img/imgCrop_RI/20210715_10_RI.jpg  2021   7  15  10
# 1     sample_img/imgCrop_RI/20210716_17_RI.jpg  2021   7  16  17
# 2     sample_img/imgCrop_RI/20210717_09_RI.jpg  2021   7  17   9
# 3     sample_img/imgCrop_RI/20210717_15_RI.jpg  2021   7  17  15
# 4     sample_img/imgCrop_RI/20210718_08_RI.jpg  2021   7  18   8
# ...                                        ...   ...  ..  ..  ..
# 1510  sample_img/imgCrop_RI/20211231_13_RI.jpg  2021  12  31  13
# 1511  sample_img/imgCrop_RI/20211231_14_RI.jpg  2021  12  31  14
# 1512  sample_img/imgCrop_RI/20211231_15_RI.jpg  2021  12  31  15
# 1513  sample_img/imgCrop_RI/20211231_16_RI.jpg  2021  12  31  16
# 1514  sample_img/imgCrop_RI/20211231_17_RI.jpg  2021  12  31  17
#
#                                         CHL_file
# 0     sample_img/imgCrop_CHL/20210715_10_CHL.jpg
# 1     sample_img/imgCrop_CHL/20210716_17_CHL.jpg
# 2     sample_img/imgCrop_CHL/20210717_09_CHL.jpg
# 3     sample_img/imgCrop_CHL/20210717_15_CHL.jpg
# 4     sample_img/imgCrop_CHL/20210718_08_CHL.jpg
# ...                                          ...
# 1510  sample_img/imgCrop_CHL/20211231_13_CHL.jpg
# 1511  sample_img/imgCrop_CHL/20211231_14_CHL.jpg
# 1512  sample_img/imgCrop_CHL/20211231_15_CHL.jpg
# 1513  sample_img/imgCrop_CHL/20211231_16_CHL.jpg
# 1514  sample_img/imgCrop_CHL/20211231_17_CHL.jpg
#
# [1515 rows x 6 columns]

# %%
print(merged_df.isna().sum())
merged_df=merged_df.dropna()
print(len(merged_df))
# Out:
# RI_file     0
# year        0
# mm          0
# dd          0
# hh          0
# CHL_file    0
# dtype: int64
# 1515

# %%
merged_df=merged_df.merge(sensory, how='left', on=dt_index)
merged_df
# Out:
#                                        RI_file  year  mm  dd  hh  \
# 0     sample_img/imgCrop_RI/20210715_10_RI.jpg  2021   7  15  10
# 1     sample_img/imgCrop_RI/20210716_17_RI.jpg  2021   7  16  17
# 2     sample_img/imgCrop_RI/20210717_09_RI.jpg  2021   7  17   9
# 3     sample_img/imgCrop_RI/20210717_15_RI.jpg  2021   7  17  15
# 4     sample_img/imgCrop_RI/20210718_08_RI.jpg  2021   7  18   8
# ...                                        ...   ...  ..  ..  ..
# 1510  sample_img/imgCrop_RI/20211231_13_RI.jpg  2021  12  31  13
# 1511  sample_img/imgCrop_RI/20211231_14_RI.jpg  2021  12  31  14
# 1512  sample_img/imgCrop_RI/20211231_15_RI.jpg  2021  12  31  15
# 1513  sample_img/imgCrop_RI/20211231_16_RI.jpg  2021  12  31  16
# 1514  sample_img/imgCrop_RI/20211231_17_RI.jpg  2021  12  31  17
#
#                                         CHL_file   풍속(m/s)   풍향(deg)  \
# 0     sample_img/imgCrop_CHL/20210715_10_CHL.jpg  0.123967  0.455556
# 1     sample_img/imgCrop_CHL/20210716_17_CHL.jpg  0.198347  0.261111
# 2     sample_img/imgCrop_CHL/20210717_09_CHL.jpg  0.305785  0.136111
# 3     sample_img/imgCrop_CHL/20210717_15_CHL.jpg  0.268595  0.261111
# 4     sample_img/imgCrop_CHL/20210718_08_CHL.jpg  0.190083  0.244444
# ...                                          ...       ...       ...
# 1510  sample_img/imgCrop_CHL/20211231_13_CHL.jpg  0.421488  0.897222
# 1511  sample_img/imgCrop_CHL/20211231_14_CHL.jpg  0.429752  0.877778
# 1512  sample_img/imgCrop_CHL/20211231_15_CHL.jpg  0.438017  0.888889
# 1513  sample_img/imgCrop_CHL/20211231_16_CHL.jpg  0.433884  0.866667
# 1514  sample_img/imgCrop_CHL/20211231_17_CHL.jpg  0.429752  0.886111
#
#         기온(°C)    수온(°C)  ...  풍향(deg).3  기온(°C).3  수온(°C).3  강수량(mm).3  \
# 0     0.826425  0.812785  ...   0.288889  0.867568  0.772321        0.0
# 1     0.847150  0.872146  ...   0.230556  0.878378  0.816964        0.0
# 2     0.795337  0.794521  ...   0.144444  0.843243  0.803571        0.0
# 3     0.834197  0.858447  ...   0.205556  0.881081  0.830357        0.0
# 4     0.823834  0.831050  ...   0.175000  0.862162  0.803571        0.0
# ...        ...       ...  ...        ...       ...       ...        ...
# 1510  0.215026  0.273973  ...   0.894444  0.216216  0.156250        0.0
# 1511  0.222798  0.269406  ...   0.872222  0.229730  0.156250        0.0
# 1512  0.217617  0.264840  ...   0.883333  0.240541  0.151786        0.0
# 1513  0.220207  0.264840  ...   0.880556  0.248649  0.147321        0.0
# 1514  0.212435  0.264840  ...   0.877778  0.251351  0.147321        0.0
#
#       풍속(m/s).4  풍향(deg).4  기온(°C).4  수온(°C).4  강수량(mm).4  적조발생
# 0      0.104803   0.291667  0.946099  0.817814   0.000000   0.0
# 1      0.126638   0.363889  0.953191  0.866397   0.000000   0.0
# 2      0.366812   0.261111  0.939007  0.846154   0.000000   0.0
# 3      0.336245   0.205556  0.940426  0.870445   0.000000   0.0
# 4      0.441048   0.308333  0.933333  0.838057   0.008772   0.0
# ...         ...        ...       ...       ...        ...   ...
# 1510   0.441048   0.938889  0.641135  0.408907   0.000000   0.0
# 1511   0.397380   0.950000  0.641135  0.408907   0.000000   0.0
# 1512   0.414847   0.955556  0.641135  0.404858   0.000000   0.0
# 1513   0.484716   0.952778  0.642553  0.404858   0.000000   0.0
# 1514   0.493450   0.988889  0.638298  0.404858   0.000000   0.0
#
# [1515 rows x 32 columns]

# %%
merged_df.isna().sum()
# Out:
# RI_file      0
# year         0
# mm           0
# dd           0
# hh           0
# CHL_file     0
# 풍속(m/s)      0
# 풍향(deg)      0
# 기온(°C)       0
# 수온(°C)       0
# 강수량(mm)      0
# 풍속(m/s).1    0
# 풍향(deg).1    0
# 기온(°C).1     0
# 수온(°C).1     0
# 강수량(mm).1    0
# 풍속(m/s).2    0
# 풍향(deg).2    0
# 기온(°C).2     0
# 수온(°C).2     0
# 강수량(mm).2    0
# 풍속(m/s).3    0
# 풍향(deg).3    0
# 기온(°C).3     0
# 수온(°C).3     0
# 강수량(mm).3    0
# 풍속(m/s).4    0
# 풍향(deg).4    0
# 기온(°C).4     0
# 수온(°C).4     0
# 강수량(mm).4    0
# 적조발생         0
# dtype: int64

# %%
merged_df.columns
# Out:
# Index(['RI_file', 'year', 'mm', 'dd', 'hh', 'CHL_file', '풍속(m/s)', '풍향(deg)',
#        '기온(°C)', '수온(°C)', '강수량(mm)', '풍속(m/s).1', '풍향(deg).1', '기온(°C).1',
#        '수온(°C).1', '강수량(mm).1', '풍속(m/s).2', '풍향(deg).2', '기온(°C).2',
#        '수온(°C).2', '강수량(mm).2', '풍속(m/s).3', '풍향(deg).3', '기온(°C).3',
#        '수온(°C).3', '강수량(mm).3', '풍속(m/s).4', '풍향(deg).4', '기온(°C).4',
#        '수온(°C).4', '강수량(mm).4', '적조발생'],
#       dtype='object')

# %%
merged_df=merged_df[['RI_file', 'CHL_file', '풍속(m/s)',
       '풍향(deg)', '기온(°C)', '수온(°C)', '강수량(mm)', '풍속(m/s).1', '풍향(deg).1',
       '기온(°C).1', '수온(°C).1', '강수량(mm).1', '풍속(m/s).2', '풍향(deg).2',
       '기온(°C).2', '수온(°C).2', '강수량(mm).2', '풍속(m/s).3', '풍향(deg).3',
       '기온(°C).3', '수온(°C).3', '강수량(mm).3', '풍속(m/s).4', '풍향(deg).4',
       '기온(°C).4', '수온(°C).4', '강수량(mm).4', '적조발생']]
merged_df
# Out:
#                                        RI_file  \
# 0     sample_img/imgCrop_RI/20210715_10_RI.jpg
# 1     sample_img/imgCrop_RI/20210716_17_RI.jpg
# 2     sample_img/imgCrop_RI/20210717_09_RI.jpg
# 3     sample_img/imgCrop_RI/20210717_15_RI.jpg
# 4     sample_img/imgCrop_RI/20210718_08_RI.jpg
# ...                                        ...
# 1510  sample_img/imgCrop_RI/20211231_13_RI.jpg
# 1511  sample_img/imgCrop_RI/20211231_14_RI.jpg
# 1512  sample_img/imgCrop_RI/20211231_15_RI.jpg
# 1513  sample_img/imgCrop_RI/20211231_16_RI.jpg
# 1514  sample_img/imgCrop_RI/20211231_17_RI.jpg
#
#                                         CHL_file   풍속(m/s)   풍향(deg)  \
# 0     sample_img/imgCrop_CHL/20210715_10_CHL.jpg  0.123967  0.455556
# 1     sample_img/imgCrop_CHL/20210716_17_CHL.jpg  0.198347  0.261111
# 2     sample_img/imgCrop_CHL/20210717_09_CHL.jpg  0.305785  0.136111
# 3     sample_img/imgCrop_CHL/20210717_15_CHL.jpg  0.268595  0.261111
# 4     sample_img/imgCrop_CHL/20210718_08_CHL.jpg  0.190083  0.244444
# ...                                          ...       ...       ...
# 1510  sample_img/imgCrop_CHL/20211231_13_CHL.jpg  0.421488  0.897222
# 1511  sample_img/imgCrop_CHL/20211231_14_CHL.jpg  0.429752  0.877778
# 1512  sample_img/imgCrop_CHL/20211231_15_CHL.jpg  0.438017  0.888889
# 1513  sample_img/imgCrop_CHL/20211231_16_CHL.jpg  0.433884  0.866667
# 1514  sample_img/imgCrop_CHL/20211231_17_CHL.jpg  0.429752  0.886111
#
#         기온(°C)    수온(°C)   강수량(mm)  풍속(m/s).1  풍향(deg).1  기온(°C).1  ...  \
# 0     0.826425  0.812785  0.000000   0.043919   0.933333  0.858974  ...
# 1     0.847150  0.872146  0.000000   0.168919   0.227778  0.905128  ...
# 2     0.795337  0.794521  0.000000   0.162162   0.266667  0.887179  ...
# 3     0.834197  0.858447  0.000000   0.152027   0.388889  0.879487  ...
# 4     0.823834  0.831050  0.012579   0.057432   0.208333  0.897436  ...
# ...        ...       ...       ...        ...        ...       ...  ...
# 1510  0.215026  0.273973  0.000000   0.243243   0.847222  0.276923  ...
# 1511  0.222798  0.269406  0.000000   0.351351   0.844444  0.330769  ...
# 1512  0.217617  0.264840  0.000000   0.277027   0.883333  0.315385  ...
# 1513  0.220207  0.264840  0.000000   0.243243   0.850000  0.323077  ...
# 1514  0.212435  0.264840  0.000000   0.212838   0.900000  0.341026  ...
#
#       풍향(deg).3  기온(°C).3  수온(°C).3  강수량(mm).3  풍속(m/s).4  풍향(deg).4  \
# 0      0.288889  0.867568  0.772321        0.0   0.104803   0.291667
# 1      0.230556  0.878378  0.816964        0.0   0.126638   0.363889
# 2      0.144444  0.843243  0.803571        0.0   0.366812   0.261111
# 3      0.205556  0.881081  0.830357        0.0   0.336245   0.205556
# 4      0.175000  0.862162  0.803571        0.0   0.441048   0.308333
# ...         ...       ...       ...        ...        ...        ...
# 1510   0.894444  0.216216  0.156250        0.0   0.441048   0.938889
# 1511   0.872222  0.229730  0.156250        0.0   0.397380   0.950000
# 1512   0.883333  0.240541  0.151786        0.0   0.414847   0.955556
# 1513   0.880556  0.248649  0.147321        0.0   0.484716   0.952778
# 1514   0.877778  0.251351  0.147321        0.0   0.493450   0.988889
#
#       기온(°C).4  수온(°C).4  강수량(mm).4  적조발생
# 0     0.946099  0.817814   0.000000   0.0
# 1     0.953191  0.866397   0.000000   0.0
# 2     0.939007  0.846154   0.000000   0.0
# 3     0.940426  0.870445   0.000000   0.0
# 4     0.933333  0.838057   0.008772   0.0
# ...        ...       ...        ...   ...
# 1510  0.641135  0.408907   0.000000   0.0
# 1511  0.641135  0.408907   0.000000   0.0
# 1512  0.641135  0.404858   0.000000   0.0
# 1513  0.642553  0.404858   0.000000   0.0
# 1514  0.638298  0.404858   0.000000   0.0
#
# [1515 rows x 28 columns]

# %% [markdown]
# # 저장
# 1. 통합된 dataframe은 list_attr.csv 로 저장합니다.

# %%
merged_df.to_csv("list_attr.csv")

# %%
ds=pd.read_csv("list_attr.csv", index_col=0)
ds
# Out:
#                                        RI_file  \
# 0     sample_img/imgCrop_RI/20210715_10_RI.jpg
# 1     sample_img/imgCrop_RI/20210716_17_RI.jpg
# 2     sample_img/imgCrop_RI/20210717_09_RI.jpg
# 3     sample_img/imgCrop_RI/20210717_15_RI.jpg
# 4     sample_img/imgCrop_RI/20210718_08_RI.jpg
# ...                                        ...
# 1510  sample_img/imgCrop_RI/20211231_13_RI.jpg
# 1511  sample_img/imgCrop_RI/20211231_14_RI.jpg
# 1512  sample_img/imgCrop_RI/20211231_15_RI.jpg
# 1513  sample_img/imgCrop_RI/20211231_16_RI.jpg
# 1514  sample_img/imgCrop_RI/20211231_17_RI.jpg
#
#                                         CHL_file   풍속(m/s)   풍향(deg)  \
# 0     sample_img/imgCrop_CHL/20210715_10_CHL.jpg  0.123967  0.455556
# 1     sample_img/imgCrop_CHL/20210716_17_CHL.jpg  0.198347  0.261111
# 2     sample_img/imgCrop_CHL/20210717_09_CHL.jpg  0.305785  0.136111
# 3     sample_img/imgCrop_CHL/20210717_15_CHL.jpg  0.268595  0.261111
# 4     sample_img/imgCrop_CHL/20210718_08_CHL.jpg  0.190083  0.244444
# ...                                          ...       ...       ...
# 1510  sample_img/imgCrop_CHL/20211231_13_CHL.jpg  0.421488  0.897222
# 1511  sample_img/imgCrop_CHL/20211231_14_CHL.jpg  0.429752  0.877778
# 1512  sample_img/imgCrop_CHL/20211231_15_CHL.jpg  0.438017  0.888889
# 1513  sample_img/imgCrop_CHL/20211231_16_CHL.jpg  0.433884  0.866667
# 1514  sample_img/imgCrop_CHL/20211231_17_CHL.jpg  0.429752  0.886111
#
#         기온(°C)    수온(°C)   강수량(mm)  풍속(m/s).1  풍향(deg).1  기온(°C).1  ...  \
# 0     0.826425  0.812785  0.000000   0.043919   0.933333  0.858974  ...
# 1     0.847150  0.872146  0.000000   0.168919   0.227778  0.905128  ...
# 2     0.795337  0.794521  0.000000   0.162162   0.266667  0.887179  ...
# 3     0.834197  0.858447  0.000000   0.152027   0.388889  0.879487  ...
# 4     0.823834  0.831050  0.012579   0.057432   0.208333  0.897436  ...
# ...        ...       ...       ...        ...        ...       ...  ...
# 1510  0.215026  0.273973  0.000000   0.243243   0.847222  0.276923  ...
# 1511  0.222798  0.269406  0.000000   0.351351   0.844444  0.330769  ...
# 1512  0.217617  0.264840  0.000000   0.277027   0.883333  0.315385  ...
# 1513  0.220207  0.264840  0.000000   0.243243   0.850000  0.323077  ...
# 1514  0.212435  0.264840  0.000000   0.212838   0.900000  0.341026  ...
#
#       풍향(deg).3  기온(°C).3  수온(°C).3  강수량(mm).3  풍속(m/s).4  풍향(deg).4  \
# 0      0.288889  0.867568  0.772321        0.0   0.104803   0.291667
# 1      0.230556  0.878378  0.816964        0.0   0.126638   0.363889
# 2      0.144444  0.843243  0.803571        0.0   0.366812   0.261111
# 3      0.205556  0.881081  0.830357        0.0   0.336245   0.205556
# 4      0.175000  0.862162  0.803571        0.0   0.441048   0.308333
# ...         ...       ...       ...        ...        ...        ...
# 1510   0.894444  0.216216  0.156250        0.0   0.441048   0.938889
# 1511   0.872222  0.229730  0.156250        0.0   0.397380   0.950000
# 1512   0.883333  0.240541  0.151786        0.0   0.414847   0.955556
# 1513   0.880556  0.248649  0.147321        0.0   0.484716   0.952778
# 1514   0.877778  0.251351  0.147321        0.0   0.493450   0.988889
#
#       기온(°C).4  수온(°C).4  강수량(mm).4  적조발생
# 0     0.946099  0.817814   0.000000   0.0
# 1     0.953191  0.866397   0.000000   0.0
# 2     0.939007  0.846154   0.000000   0.0
# 3     0.940426  0.870445   0.000000   0.0
# 4     0.933333  0.838057   0.008772   0.0
# ...        ...       ...        ...   ...
# 1510  0.641135  0.408907   0.000000   0.0
# 1511  0.641135  0.408907   0.000000   0.0
# 1512  0.641135  0.404858   0.000000   0.0
# 1513  0.642553  0.404858   0.000000   0.0
# 1514  0.638298  0.404858   0.000000   0.0
#
# [1515 rows x 28 columns]
